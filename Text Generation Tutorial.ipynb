# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
from tensorflow import keras
import tensorflow as tf
import numpy as np
import random
import sys
import io
import requests
import re

# %% [markdown]
# ## This tutorial is

# %%
r = requests.get("https://data.heatonresearch.com/data/t81-558/text/"\
                 "treasure_island.txt")
raw_text = r.text

# %%
processed_text = raw_text.lower()
processed_text = re.sub(r'[^\x00-\x7f]',r'', processed_text) #Removes everything that is not ASCII

# %%
print('corpus length:', len(processed_text)) #length of the document 

chars = sorted(list(set(processed_text)))
print('total chars:', len(chars)) #total characters. Saves memory as we've stored the characters. 
char_indices = dict((c, i) for i, c in enumerate(chars)) #Encodes the character to the ID, to save space (as stated above)
indices_char = dict((i, c) for i, c in enumerate(chars)) #Encodes the ID to the character, so we can cross reference the two to decode the actual word
# Out:
# corpus length: 397400
# total chars: 60

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40 #Sequence size. Given these 40 characters, try to generate the next character. 
step = 3 #Move forwards three characters for each 40 character chunk. Having it larger than 1 prevents redudant sequences
sentences = []
next_chars = []
for i in range(0, len(processed_text) - maxlen, step):
    sentences.append(processed_text[i: i + maxlen])
    next_chars.append(processed_text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 132454

# %% [markdown]
# ## Vectorization Process
# The following code vectorizes the dataset. This changes it to the actual X and Y, which will go into the the model.
# This is separated by indices
# Notice how x organized.
# ##### X Values
#     X[0] is the total sequences (len(sentences))
#     X[1] is the input vector
#     X[2] is the dummy variables.
# ###### Y Values
#     y[0] is the total sequences
#     y[1] is the dummy variables (the expected characters) like X[2].

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool) 
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars)))) #One LSTM Layer, 
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               96768
# _________________________________________________________________
# dense (Dense)                (None, 60)                7740
# =================================================================
# Total params: 104,508
# Trainable params: 104,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
#This is the function that actually creates the output text.  
#preds are the output neurons, which are the 60 output probabilities that we saw before (the dummy variables)
#We are also normalizing the value into a softmax so they sum to 100
#Temperature => 1.0 is the character with the highest probability. 0 is more random. 

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
#This is the text generator

def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print("****************************************************************************")
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(processed_text) - maxlen - 1) #Display it 
    for temperature in [0.2, 0.5, 1.0, 1.2]: #Display it for these specific temperatures. 
        print('----- temperature:', temperature)

        generated = ''
        sentence = processed_text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"') #This is the seed, it is used to generate the 40 characters and allow it to keep going.
        sys.stdout.write(generated)

        for i in range(400): #Generate it for the next 400 characters. 
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = indices_char[next_index]

            generated += next_char #Add whatever you generated onto what you generated. At some point, the seed will generate off your generated texts. 
            sentence = sentence[1:] + next_char #output the text. 

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
# Ignore useless W0819 warnings generated by TensorFlow 2.0.  Hopefully can remove this ignore in the future.
# See https://github.com/tensorflow/tensorflow/issues/31308
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# Fit the model
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback], 
          )
# Out:
# Epoch 1/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.3800****************************************************************************
# ----- Generating text after Epoch: 0
# ----- temperature: 0.2
# ----- Generating with seed: "y--fiction.] i. winter, milo, 1888-1956,"
# y--fiction.] i. winter, milo, 1888-1956,' says have the stockade, and the stockade, and the boatswain soon and the stockade, and the first the sea the worst and a strong of the stockade, and the boats, and the sight the stranger to and the stockade, and the boats and me the woods and the shore of the stockade, and the shores of the first and the shore, and the boats, and the sure is a pipe of the stockade, and the first the man the stoc
# ----- temperature: 0.5
# ----- Generating with seed: "y--fiction.] i. winter, milo, 1888-1956,"
# y--fiction.] i. winter, milo, 1888-1956, gentlemeng and the sit in the good on them with the stockade,
# under the brace.
#
# "and i've sting the captain, "you are i say say your eyen in a horsed and the captain and i had been my father the bottle and for a man of the stockade. if it was the printing that
#
#
# ----- temperature: 1.0
# ----- Generating with seed: "y--fiction.] i. winter, milo, 1888-1956,"
# y--fiction.] i. winter, milo, 1888-1956, boy, founden," and. if
# the doctons from thum, as for the squire.    the avort the worthers, on
# strought donf, and when i did a grokee round the anchorage
# more things and scraits, and run weng shoulder and doctor a
# time, that's voices you seen with roar would have the coraclerey. there we groun things on to their nappx. now each, and for a high him, and as
# doctory, and began two searar i fell
# ----- temperature: 1.2
# ----- Generating with seed: "y--fiction.] i. winter, milo, 1888-1956,"
# y--fiction.] i. winter, milo, 1888-1956,p whom
# not hunter, or beside your 'eyne, not kinds dickyqu,"
#
# the _hispaning, pecket
# little to beg timolish
# ensoot helped upon, and to
# part," share, and a whwound of
# sad?, to mobed and grow changed to hand the
# cruirs soon lest the stocked, sir, with loctory
# harmed meracred him .
#
# "they pew's words is all sail, "twyrides got haf faces in the youngest tell accopsarly--time agren them
# ove
# 1035/1035 [==============================] - 68s 66ms/step - loss: 1.3798
# Epoch 2/60
# 1031/1035 [============================>.] - ETA: 0s - loss: 1.3583****************************************************************************
# ----- Generating text after Epoch: 1
# ----- temperature: 0.2
# ----- Generating with seed: " "are you afraid of blood?"
#
# "no, sir,"
#  "are you afraid of blood?"
#
# "no, sir," said the squire and the ship's seemed to be sure to be sure to be sure to be sure to and started the same me to the same time the single of the same me to the wood of the said, and the ship's discutled to the same sound of the same me to the island, and the straight began to the same time the said the same take the said the sea
# straight to be sure to his shoulder the same to the same the man th
# ----- temperature: 0.5
# ----- Generating with seed: " "are you afraid of blood?"
#
# "no, sir,"
#  "are you afraid of blood?"
#
# "no, sir," said silce, as they silver, and brought to the corner of like a spot his hand and the chanted.
#
# "there where the same same his doctor livesey, and over the black to passed and continued and seemed me, but you have still be all sown to be the stick at the ship!" as i found my heart he took the corner of the oddry cut all the same between the most stand of the wood of the speak to no and that ba
# ----- temperature: 1.0
# ----- Generating with seed: " "are you afraid of blood?"
#
# "no, sir,"
#  "are you afraid of blood?"
#
# "no, sir," he was, i was nevre in this for a bottorase, sealls, with the towast havin to be but get well payouy or two, of
# the copyarring said go anywhere upto the swick if a sight no partur 'woundpiciteder, soriting himself bekine this seal in raid mate.
#
# the shalked, this fer siinion, and for diftity and most
# had my 'emn at
# the party on the isteen. the scutsck. as i had soil tring flove roads we had
# ----- temperature: 1.2
# ----- Generating with seed: " "are you afraid of blood?"
#
# "no, sir,"
#  "are you afraid of blood?"
#
# "no, sir," lo!" the squire.  herekingqove goods that i letther, of like that therpen was that? notlightly hawkins about done upot the usunk.     asdon.
#
# captain all had, it hered im set use upon the schooner dibrieds tog that ogh against to a
# like a trucess and was inllutaated.
#
# unlow on, folut,, cllase, you geth."
#
# there was, "doctor likele,, arsagen't like to be say,"
#  "he's bunk. there won'e you
# 1035/1035 [==============================] - 73s 70ms/step - loss: 1.3584
# Epoch 3/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.3423****************************************************************************
# ----- Generating text after Epoch: 2
# ----- temperature: 0.2
# ----- Generating with seed: "pleasure, that lay waiting there for eac"
# pleasure, that lay waiting there for each of the stockade, and the bright of the treasure, and the bright of the stockade, and the bright of the stockade of the stockade, and the bright of the treasure the black one of the stockade, and
# the doctor of the stockade, and the same the same to see the trees were and the stockade, and the bright of the stockade, and the bright of the stockade of the stockade, and the same more the stockade.
# ----- temperature: 0.5
# ----- Generating with seed: "pleasure, that lay waiting there for eac"
# pleasure, that lay waiting there for each before the trees were soon and the wind or the now, where the was before the stranging as we had a starring to the captain on the treasure, and the brought to a nection, and the worse perhaps, and a sound of the trees to stard and be in the captain.
#
# the captain, which were a tall geve hand of his gross so that carried the best had a stet in the same time i was the most and the doctor of the t
# ----- temperature: 1.0
# ----- Generating with seed: "pleasure, that lay waiting there for eac"
# pleasure, that lay waiting there for each that you may le's in aorawudedly. they had stopped them before, and not go please for to saying to that redruthrins; they dakiverss_ up my rederbers, must lived
# outs. it was i've a given the defehauling before
# shigifr passed smill," said him up should runied him down, i outing the cookan cut, speaking, not a mark on the bay.
#
# i stoll the pirates on--this ruught of the lallowney, eight give.
# ----- temperature: 1.2
# ----- Generating with seed: "pleasure, that lay waiting there for eac"
# lleasure, that lay waiting there for each shons, perble olhe rewayin ggings and daits. "to be barted aim:sparigely, gentleman my , very like a lati; and he was still, a than, but above out my nowle case therelainetupily meent--whemish-in, o, all 'onks' anchorage on his faclook flower seconsue-boost-tremarvation, what a tiln, and the meanted. i've our ald.
# "to do.
# look, as and no, i'daltofls, now, or i think aiso achaots, now, usure,
# 1035/1035 [==============================] - 69s 67ms/step - loss: 1.3423
# Epoch 4/60
# 1031/1035 [============================>.] - ETA: 0s - loss: 1.3289****************************************************************************
# ----- Generating text after Epoch: 3
# ----- temperature: 0.2
# ----- Generating with seed: "?
# you daren't show face in bristol afte"
# ?
# you daren't show face in bristol after his and the straight had a pickay, and the stranger of the captain stand and the stockade, and i had the stockade, and the stockade, and he was a sound of the stockade, and the ship's shipped the treasure out and stepped to the captain stand and been sharp and been the stockade. i was a stood he was stand and the stockade, and i should see the stockade, and the ship's see the stockade, and the s
# ----- temperature: 0.5
# ----- Generating with seed: "?
# you daren't show face in bristol afte"
# ?
# you daren't show face in bristol after of the stockade, and the for and stand of the houst of the stockade, we away, slack dog, the stranger to see the color, in the man the booty dirk, of the starr, and a companions of the thing to his for the treasure of a shipmate off his hearte a copy this work and been swall off the statul
# and a south. i say, my heart very face, but the coracle and companions and help in the captain.
#
# "i saw
# ----- temperature: 1.0
# ----- Generating with seed: "?
# you daren't show face in bristol afte"
# ?
# you daren't show face in bristol after's foot of his stratch, gave, took the starring to
# wordoug stateers song, out as while dogngiags outisage, you cholked me out of each; and i kind of
# noo a thiction--shelve enough coon back and deatively agrecertain.
#
# high, i could you, think, you're my mots no shoking
# interriss. the
# most the project gutenberg-tm proted as the perlibly dobow the bens har
# sont that the word ripatenround i lo
# ----- temperature: 1.2
# ----- Generating with seed: "?
# you daren't show face in bristol afte"
# ?
# you daren't show face in bristol after the blone with, 'ome, i'm shot had scometufiner, this for shont
# , don'ell the gegt agond thing of it; so hw's bfishess. you and captain, by the sure.r
#
#     xxv, forecable in't back now; but i're never you volllsening in a up and, so bill; but
# oglloones on the gorsion," again instling of the lowly
# fairtly. id ladsing the log heavioulu
# -thern , shis; reconcent, alth, must
# -  yho-go horse had
# 1035/1035 [==============================] - 80s 77ms/step - loss: 1.3294
# Epoch 5/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.3148****************************************************************************
# ----- Generating text after Epoch: 4
# ----- temperature: 0.2
# ----- Generating with seed: "d it was one of the
# other four who fell"
# d it was one of the
# other four who fellow and the sure, and the captain.
#
# "that's a bright that was the captain, and a bree
# silver to be sure the same black was a surprise of the stockade, and the squire was the ship and a picest of the stockade, and the gigs and the captain silver and the captain silver, and the captain.
#
# "why, i did," said he, "for i could not say i can the sure, and the captain silver and the still of the story
# ----- temperature: 0.5
# ----- Generating with seed: "d it was one of the
# other four who fell"
# d it was one of the
# other four who fellow and been to me a would see a great for the
# comass there was the suresible certainly on the captain like the pards and the
# dick me when i paid to my mind out another words and hard by the doctor
# had been silver, for the sail, silver would have carried by the story, and stand and a pick still had been
# same me book here and seen a places and see and a great pitated to claptain smollett had bef
# ----- temperature: 1.0
# ----- Generating with seed: "d it was one of the
# other four who fell"
# d it was one of the
# other four who fellow's buck a gentle, and
# ebourred, there was out three unleaked began him
# electroner, eccanet, app intermed i'll this men that three othermed me, and like,
#
#    ope my now lipricing accessed i
# pratecumish, but slap to his shout,
# sin
# go del had comech beaul very pipe
# and fro; but though you're not the parrion, and my tillorss, and he tolling every first all the log
# so to fear
# was black, it
# ----- temperature: 1.2
# ----- Generating with seed: "d it was one of the
# other four who fell"
# d it was one of the
# other four who fellow avoighland, that
# usiles watne blach fing what you, ivanched i'll
# band on.
#
# "why," nutch," ," says noripency. you'll, fough, thot project dk unkestt.
#
# "if eegue; and now easy puned, bluck. slipping on 1bey wromfse, tos cappes, "peeced it but when these veatits that, and i say.
# tells are, ar but im! cruining law moring
# to be thatere's clupceet, lia's certainly healt you
# have there crift,
# 1035/1035 [==============================] - 73s 71ms/step - loss: 1.3151
# Epoch 6/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.3073****************************************************************************
# ----- Generating text after Epoch: 5
# ----- temperature: 0.2
# ----- Generating with seed: "ws. here's cap'n flint--i calls my parro"
# ws. here's cap'n flint--i calls my parrot, and shipmate was a suddenly
# silver, and the same time, and the ship's down the captain.
#
# "well, i'll tell you all the captain, "have a sure to the captain, and the same more and the part of the captain of the captain. "but i was a couldners and stand of the stockade,
# and the ship was all the strange like a good superst, and the black was a charter and the captain.
#
# "well, we do think it w
# ----- temperature: 0.5
# ----- Generating with seed: "ws. here's cap'n flint--i calls my parro"
# ws. here's cap'n flint--i calls my parrot to the captain. "what we were a red to be sure, and the sprang along at a treasure we may lay to the that of the stockade of the cabin of the storas to curres to the captain. "if he was over, and the chisp of the coracle so the
# captain, and the spit, by the captain. we had stand in plain and a challor we were all of
# once the captain, and so the long to the parts, and return and the gigs old ha
# ----- temperature: 1.0
# ----- Generating with seed: "ws. here's cap'n flint--i calls my parro"
# ws. here's cap'n flint--i calls my parrot. "and i. it was scarce, and this marsains and searar-and
# it was a pleasure your man a
# sanghite of the gage, feen the cleaning.
#
# we were we know weardle come like, by distwore
# sart, silver, we far touch astaun piee. "to thesechous mus! they come all the stamps, a gen not so would shealt of
# af of him own heach on if the thack was you down with him that had
# good a man," said who's under. he
# ----- temperature: 1.2
# ----- Generating with seed: "ws. here's cap'n flint--i calls my parro"
# ws. here's cap'n flint--i calls my parror.
#
# "sciltighting noj his."
#
# keney greadly
# way!" cried before the . realinble blester's
# right sea heren. the sain.
#
#     he
# , transupil, he would."'
# helt strets would silver. we was untill have back outla.d, and right
# sige. "foo-foon of erigate. one aki not never
# swoney, enough, but with ho, all watch, notgly like , dingless; by violanns; "that?"
#
# once north."
#
# farth deck lade, very
# 1035/1035 [==============================] - 71s 69ms/step - loss: 1.3074
# Epoch 7/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2978****************************************************************************
# ----- Generating text after Epoch: 6
# ----- temperature: 0.2
# ----- Generating with seed: " busy all day in the cave,
# packing the "
#  busy all day in the cave,
# packing the shore of the captain. "well, who had seen the stockade, and the starn of the stockade, and as i was so that the parrot of the
# story and the project gutenberg-tm the trees was a sure than the boat the project gutenberg-tm the burn the shore of the worst and the ship's seaman to the east of the corner of the stockade, and the starr of the shore of the story
# and the stoward the side of the stockade
# ----- temperature: 0.5
# ----- Generating with seed: " busy all day in the cave,
# packing the "
#  busy all day in the cave,
# packing the stockade, like the sign for the stoward and the rest and the best of the torn was pirates before it the brought there of the fellow at the time the project gutenberg-tm all was all the road. i was speak of
# the stockade, and the ship's done as we may looked there was not the sure in a little were and hands ben gunn's some out and concearted to and had all comed a still that he arming that when i c
# ----- temperature: 1.0
# ----- Generating with seed: " busy all day in the cave,
# packing the "
#  busy all day in the cave,
# packing the nelly, and i opened his in the eights
#      you a crownan how it were eleary liphin's pllass was,
# and allucurr. i had here, you have been three chappor, all. i than a witence up his land make and
# work on his silver, i're had alreadve had been
# rishorast, and tiald 'um he crownes, pain waterfhionzed had been care and by this rumber strigg in hold's capsose till
# if i warn the horso own bend busin
# ----- temperature: 1.2
# ----- Generating with seed: " busy all day in the cave,
# packing the "
#  busy all day in the cave,
# packing the most very fancabter
#  the trick like, opd thinged in the
# down the cry wasy threen me usore. inderilance in an
# ben indotation uselassed all. and seemed in turned your had
# election i am borth, and alacadeasarmom forth or men rensurned, in tiotles dead
# spemre.
#
# indeed, you isal would, soies--vaytery, misside. but?"
#
# "murge runt, eh?"
#
# "and we had tell, it is and, doctor before
# mes
# i tabe
# 1035/1035 [==============================] - 69s 67ms/step - loss: 1.2978
# Epoch 8/60
# 1032/1035 [============================>.] - ETA: 0s - loss: 1.2898****************************************************************************
# ----- Generating text after Epoch: 7
# ----- temperature: 0.2
# ----- Generating with seed: "that i had found the boat, you would hav"
# that i had found the boat, you would have been the stranger in the starring to the stockade, and a stern of the stranger the stranger the blind
# the stockade, and the sure is and standing the stockade, and the boy a
# companions of the stockade, and while i had been
# spoke the starring his shores and the captain stand of the stockade, and the boy and been say in the starring and the books of the captain beside the starring and beside a s
# ----- temperature: 0.5
# ----- Generating with seed: "that i had found the boat, you would hav"
# that i had found the boat, you would have been the most fell out the swallows, and the
# bestering more that the cabin and a lands, and i insed
# of the chair. a
# what i could hear him the pleasant all the
# doctor livesey, and the doctor, but i had ented of the captain starped the stockade. the starring to be supporting the starr
# to of cooking the bowss. silver shoulder the sure even particular the blind as a his was my mother project gu
# ----- temperature: 1.0
# ----- Generating with seed: "that i had found the boat, you would hav"
# that i had found the boat, you would have tile as you'me at the copy he had pinching the sage and discalled. the doctor.
#                                                                                                   xxx 1.   spilasivg. he said, "your first cook numped board; he went the twollorge as hungred, and i tried the cave.
#
# i had let; beach foot. but these trouting. yet in not under presesswad; and i'll
# dead, there? well,
# ----- temperature: 1.2
# ----- Generating with seed: "that i had found the boat, you would hav"
# that i had found the boat, you would have he do stellelt, must quick
# of mes. fwith along hawkins0ly. 'serve his more we papet, i not mo long we were blow him i reckon a max re'spying vorse, and you
# would long--wed and know thes
# would neves "do-to at heard jim," reading out.
#
# i still account; the ncage, and he don't be missinage
# unlitter
# not till i began dony; and the speed which
# was long tone of gan. and a turn. fir them.
#
# at
# 1035/1035 [==============================] - 72s 70ms/step - loss: 1.2901
# Epoch 9/60
# 1031/1035 [============================>.] - ETA: 0s - loss: 1.2830****************************************************************************
# ----- Generating text after Epoch: 8
# ----- temperature: 0.2
# ----- Generating with seed: "t, and i soon saw what they were. one,
# "
# t, and i soon saw what they were. one,
# and i was a soon and the ship the sound of the cook
# was a soon and a cooks and the ship what i could take a soon and a come to the ship when i had a foor and the partion and the sound
# the cook was the ship the sound and the ship and a companions of the cook
# was a man was a soon and the cook was a soon and the sea
# on the stockade, and the ship in the sound of the corner of the stockade, and i w
# ----- temperature: 0.5
# ----- Generating with seed: "t, and i soon saw what they were. one,
# "
# t, and i soon saw what they were. one,
# that place of the captain soon of the stockade, and the houses of the toge as that we were
# stord. but i was a soon as the colors and for a pipe of the cooking at last in the cooking to the eavy that of the deck and
# been hands against the doctor of the corner of it on the parr, and then the ship one of the rough, and the ship the stockade, and then we lay to that foretripsially good against a cap
# ----- temperature: 1.0
# ----- Generating with seed: "t, and i soon saw what they were. one,
# "
# t, and i soon saw what they were. one,
# your try
#                                  adm lad about the astain quiet. i co in't a linglessing, reastwars for a traster like a comection yet fire lawter blard; he my pont
# enerer that was accanc one of the trees, everythanted he gut the whole soon; onled
# soon safe in the thought; ta's sever's man to
#
# ----- temperature: 1.2
# ----- Generating with seed: "t, and i soon saw what they were. one,
# "
# t, and i soon saw what they were. one,
# helt--"lawaty, 'and?" i
# ooar up on very, drow the roons into dickners of that pitch
# the cowainers is story their down stood againloking was good trates and the powb-iwarke.tegune
# lookly in silence, with your orn evethandence? "and i was to the good place dis'--awarkent, at this man outh will
# beaing that, cectie, and not
#
# 1035/1035 [==============================] - 81s 78ms/step - loss: 1.2830
# Epoch 10/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2772****************************************************************************
# ----- Generating text after Epoch: 9
# ----- temperature: 0.2
# ----- Generating with seed: "ieve him thoroughly honest; some of the "
# ieve him thoroughly honest; some of the stores of the shore. the ship in the shore. i had been all the shore. the ship's
# shoulder island with the shore. we had to the trees of the more and shore. the seaged, and the sea-cook. the ship's ship the shore. i'm story and the shore. the same time and shore, and the ship's shore, and the same and the ship to the shore. i'm story
# and the shore. i was a shore, and the same was its and the ship
# ----- temperature: 0.5
# ----- Generating with seed: "ieve him thoroughly honest; some of the "
# ieve him thoroughly honest; some of the shoulders to the sea of the crowness; he had not shipped and the captain side. first
# with the shore, and should to see, and then the shipled the shore. it was a man that was a shores of the shore. the sure
# took the man with the silver and a ship. and looked to me of a mornance, and the point, and anything all looking for a paper. it's
# the mainsail hands as he had a man was before the sailed and
# ----- temperature: 1.0
# ----- Generating with seed: "ieve him thoroughly honest; some of the "
# ieve him thoroughly honest; some of the men soon, and reary, many up with chanfess,
# an of the soul, shimment to more, and thought my knanchopsor
# appoateces and fingers, and a coulat to truce acliles where
# leaving, jim. much stouling man would see had stated torsh him husgered
# "not but we ho degalee; and, even it, but knew
# the doctor, ser, you know you; though, he but decenseded, as he was a atyone
# to i crued; right the ashore for
# ----- temperature: 1.2
# ----- Generating with seed: "ieve him thoroughly honest; some of the "
# ieve him thoroughly honest; some of the worned
# saved, with you, and dead byojmy doing me, as
# iriesle below he goit. we
# end was thought a word of his canson turr! north'sastay uspahessing
# surret, fiddlusue to lug.
#       i. brave h"meverting to teer we stuach the mail cans, order
# hotoon. he can undite-treeshest fever, keypbiations.
#
# oh, that's ture, and i don, shores; and i should dowes annging if
# there's
# arman," shalled i sat.
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2772
# Epoch 11/60
# 1032/1035 [============================>.] - ETA: 0s - loss: 1.2689****************************************************************************
# ----- Generating text after Epoch: 10
# ----- temperature: 0.2
# ----- Generating with seed: "ong with him, was admitted at a word int"
# ong with him, was admitted at a word into the side of the ship, and the captain.
#
# "well, i said, "you was shore and it was a silver of the colfes of the colfest
# and blood, and the man would be surpest of the captain.
# "doctor livesey," said he, "well, i said, and the silver of the ship here and the signan of the same bloods and the ship was the same time i was the shore.
#
# "doctor's dead," said the captain, "don't her some to the
# ----- temperature: 0.5
# ----- Generating with seed: "ong with him, was admitted at a word int"
# ong with him, was admitted at a word into the
# sea of the same isle of old best i was market,
# no looking for the silver, as much and dessed his shortle
# dessed to do to be sure it i done in the most hear the parron would our pring of the party of the treasure.
#
# "and without here in it, and the silver was like a place strange things and before our own the captain smolledt we was pipe
# to be sure the captain on the captain. "well, i st
# ----- temperature: 1.0
# ----- Generating with seed: "ong with him, was admitted at a word int"
# ong with him, was admitted at a word into rose, and
# i same laid our were in which holding, and without
# this albook into the captain, anders end ofden, inselvess, stright;
#
# "pucknes? he shut; looked ? the sipple of hands on the retwnoity someming to be
# flaged, and
# plaining proted little grahers; thone refand, and a lest men
# before our kind.
#
# "you or row lard?" cried you was fljea side weekling, and it wonder
# of roved, which of
# ----- temperature: 1.2
# ----- Generating with seed: "ong with him, was admitted at a word int"
# ong with him, was admitted at a word into a upfress came he had onder all got
# me acch, and at the i
# sa; looked, that's sorts
# obson't then heading someng,
# sometions."
#
# lite and
# slaved quests, someming enjoye miding me or
# junner, i'll know, and i spy-moct,
# but. we were's to shon whanien one datiel
# "boy, darks, 'em sut, mateser, be ben cape, a cabing.
#
# closd _or dire, and doctor long upstwaly
# mostly you up, but black, as longe
# 1035/1035 [==============================] - 78s 76ms/step - loss: 1.2691
# Epoch 12/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.2637****************************************************************************
# ----- Generating text after Epoch: 11
# ----- temperature: 0.2
# ----- Generating with seed: " old
# tattered sea-cloak with a hood tha"
#  old
# tattered sea-cloak with a hood that i was all the starring of the starr of the starn or the strange to the cabin and the sail and the sand, and the stockade.
#
# the stockade, and a still and the brought the sailing and the straighbeward of the captain said one of the starn or the starr
# still and the sandy and stand of the stockade.
#
# the stockade, and so the same time the first the strange to the stockade, and a still and the ca
# ----- temperature: 0.5
# ----- Generating with seed: " old
# tattered sea-cloak with a hood tha"
#  old
# tattered sea-cloak with a hood that i was still and the sea
# still believe bearing, and the round one of the captain.
#
# this was a still which was the country, as i could hear the thiste of the other his chull of the sure with his grasp and one of the stockade, and a while of the sea our state was a sailing the stockade on ingreat all at the others as the
# starr, captain, and some of the house, and the meantime before the same
# t
# ----- temperature: 1.0
# ----- Generating with seed: " old
# tattered sea-cloak with a hood tha"
#  old
# tattered sea-cloak with a hood that some tather in a project gutenberg-tm creed straig till it wonder.
#                                                                                                                 c
# omo; s
# i. for the you were like allimate, to builed us."
#
# "airlight is from mr. trelawney, silence in a project gutenberg-tm gray cup beewber clump of the pattien with georgeand crafe, which wet difever had been
# p
# ----- temperature: 1.2
# ----- Generating with seed: " old
# tattered sea-cloak with a hood tha"
#  old
# tattered sea-cloak with a hood that a gray try or my kidd. "your halled they would came, was acl gbeen and to what green her huaght.
# guien' wae. but run," said silver, as itjiccanes dilobs, and what int.
#  the partyous, troy loo's
# tall weally now his
# run!"
#
# "bren thok in eithees dow enough up with arm.
#  one meaicly a stettying with there had heref-hereed.
#
# i reft 'em leke indeaty, and what
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-97d531a0f32a> in <module>
#      11           batch_size=128,
#      12           epochs=60,
# ---> 13           callbacks=[print_callback],
#      14           )
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1135           epoch_logs.update(val_logs)
#    1136
# -> 1137         callbacks.on_epoch_end(epoch, epoch_logs)
#    1138         training_logs = epoch_logs
#    1139         if self.stop_training:
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     414         if numpy_logs is None:  # Only convert once.
#     415           numpy_logs = tf_utils.to_numpy_or_python_type(logs)
# --> 416         callback.on_epoch_end(epoch, numpy_logs)
#     417
#     418   def on_train_batch_begin(self, batch, logs=None):
#
# <ipython-input-10-205f6aa1fb74> in on_epoch_end(epoch, _)
#      21                 x_pred[0, t, char_indices[char]] = 1.
#      22
# ---> 23             preds = model.predict(x_pred, verbose=0)[0]
#      24             next_index = sample(preds, temperature)
#      25             next_char = indices_char[next_index]
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1577           use_multiprocessing=use_multiprocessing,
#    1578           model=self,
# -> 1579           steps_per_execution=self._steps_per_execution)
#    1580
#    1581       # Container that configures and calls `tf.keras.Callback`s.
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1115         use_multiprocessing=use_multiprocessing,
#    1116         distribution_strategy=ds_context.get_strategy(),
# -> 1117         model=model)
#    1118
#    1119     strategy = ds_context.get_strategy()
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     360       return flat_dataset
#     361
# --> 362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
#     364     dataset = self.slice_inputs(indices_dataset, inputs)
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func)
#    1725       Dataset: A `Dataset`.
#    1726     """
# -> 1727     return FlatMapDataset(self, map_func)
#    1728
#    1729   def interleave(self,
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func)
#    4121     self._input_dataset = input_dataset
#    4122     self._map_func = StructuredFunctionWrapper(
# -> 4123         map_func, self._transformation_name(), dataset=input_dataset)
#    4124     if not isinstance(self._map_func.output_structure, DatasetSpec):
#    4125       raise TypeError(
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3369       with tracking.resource_tracker_scope(resource_tracker):
#    3370         # TODO(b/141462134): Switch to using garbage collection.
# -> 3371         self._function = wrapper_fn.get_concrete_function()
#    3372         if add_to_graph:
#    3373           self._function.add_to_graph(ops.get_default_graph())
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    2937     """
#    2938     graph_function = self._get_concrete_function_garbage_collected(
# -> 2939         *args, **kwargs)
#    2940     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2941     return graph_function
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2904       args, kwargs = None, None
#    2905     with self._lock:
# -> 2906       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2907       seen_names = set()
#    2908       captured = object_identity.ObjectIdentitySet(
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapper_fn(*args)
#    3362           attributes=defun_kwargs)
#    3363       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3364         ret = _wrapper_helper(*args)
#    3365         ret = structure.to_tensor_list(self._output_structure, ret)
#    3366         return [ops.convert_to_tensor(t) for t in ret]
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in _wrapper_helper(*args)
#    3297         nested_args = (nested_args,)
#    3298
# -> 3299       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3300       # If `func` returns a list of tensors, `nest.flatten()` and
#    3301       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     253       try:
#     254         with conversion_ctx:
# --> 255           return converted_call(f, args, kwargs, options=options)
#     256       except Exception as e:  # pylint:disable=broad-except
#     257         if hasattr(e, 'ag_error_metadata'):
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     530
#     531   if not options.user_requested and conversion.is_whitelisted(f):
# --> 532     return _call_unconverted(f, args, kwargs, options)
#     533
#     534   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337
#     338   if kwargs is not None:
# --> 339     return f(*args, **kwargs)
#     340   return f(*args)
#     341
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in slice_batch_indices(indices)
#     352       if self._partial_batch_size:
#     353         index_remainder = dataset_ops.DatasetV2.from_tensors(array_ops.slice(
# --> 354             indices, [num_in_full_batch], [self._partial_batch_size]))
#     355         flat_dataset = flat_dataset.concatenate(index_remainder)
#     356
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\ops\array_ops.py in slice(input_, begin, size, name)
#    1078     A `Tensor` the same type as `input_`.
#    1079   """
# -> 1080   return gen_array_ops._slice(input_, begin, size, name=name)
#    1081
#    1082
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in _slice(input, begin, size, name)
#    9254   # Add nodes to the TensorFlow graph.
#    9255   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 9256         "Slice", input=input, begin=begin, size=size, name=name)
#    9257   _result = _outputs[:]
#    9258   if _execute.must_record_gradient():
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     468               dtype=dtype,
#     469               as_ref=input_arg.is_ref,
# --> 470               preferred_dtype=default_dtype)
#     471         except TypeError as err:
#     472           if dtype is None:
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     336                                          as_ref=False):
#     337   _ = as_ref
# --> 338   return constant(v, dtype=dtype, name=name)
#     339
#     340
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     262   """
#     263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 264                         allow_broadcast=True)
#     265
#     266
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     284   attrs = {"value": tensor_value, "dtype": dtype_value}
#     285   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
# --> 286       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     287
#     288   if op_callbacks.should_invoke_op_callbacks():
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     591     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     592         op_type, inputs, dtypes, input_types, name, attrs, op_def,
# --> 593         compute_device)
#     594
#     595   def capture(self, tensor, name=None, shape=None):
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3483           input_types=input_types,
#    3484           original_op=self._default_original_op,
# -> 3485           op_def=op_def)
#    3486       self._create_op_helper(ret, compute_device=compute_device)
#    3487     return ret
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1973         op_def = self._graph._get_op_def(node_def.op)
#    1974       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 1975                                 control_input_ops, op_def)
#    1976       name = compat.as_str(node_def.name)
#    1977     # pylint: enable=protected-access
#
# c:\users\ry88\documents\personal\env\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1810
#    1811   try:
# -> 1812     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1813   except errors.InvalidArgumentError as e:
#    1814     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:
